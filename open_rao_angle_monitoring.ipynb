# %% [markdown]
# # OpenRAO Angle Monitoring in pyPowsybl

# %% [markdown]
# In this notebook, we'll explore how OpenRao monitoring algorithms work.
# For network situations with angle or voltage overloads, the monitoring module will try to relieve these constraints by applying remedial actions.
#
# The first step is to install pypowsybl and import the library.

# %%
pip install pypowsybl==1.15.0

# %%
import pypowsybl as pp
from pypowsybl.rao import Parameters as RaoParameters

# %%
# set up logging
import logging
logging.getLogger('powsybl').setLevel(logging.INFO)
logging.basicConfig(format='%(asctime)s - %(levelname)s - %(name)s - %(message)s')

# %% [markdown]
# Let's load a simple 3 node network.
# - VL1 voltage level contains a generator producing 100 MW.
# - VL2 voltage level contains a load consuming 100 MW.
# - VL1 and VL3 are connected by a PST.
# - VL2 and VL3 are connected by 2 lines, one of with has infinite resistance : that's why it has no power flowing through it.

# %%
network =  pp.network.load("data/rao/monitoring/network.xiidm")
network.get_network_area_diagram()

# %% [markdown]
# Now, let's run a loadflow on this network. We'll then be able to assess which lines are overloaded.

# %%
pp.loadflow.run_ac(network)
network.get_network_area_diagram()

# %% [markdown]
# The monitoring algorithm is run after a RAO has been run, on a network on which are applied the remedial actions optimized during the RAO to optimize flow CNECs.
# To relieve Angle/Voltage CNECs, we won't be optimizing remedial actions because modelling the impact of remedial actions on angle/voltage values is highly complex and non linear. Instead, we'll be checking application conditions and applying remedial actions until CNECs are relieved.
#
# To run a monitoring, we need to load the following inputs:

# %%
parameters = RaoParameters.from_file_source("./data/rao/monitoring/rao_parameters.json")
load_flow_parameters = parameters.search_tree_parameters.loadflow_and_sensitivity_parameters.sensitivity_parameters.load_flow_parameters

# %% [markdown]
# As stated previously, first we'll run a rao and save the rao_result. This rao_result will be used to load activated remedial actions during the monitoring module.

# %%
crac = pp.rao.Crac.from_file_source(network, "./data/rao/monitoring/angle_monitoring/angle_monitoring_simple_case_with_RA_on_load.json")

# %%
rao_runner = pp.rao.create_rao()

# %%
rao_result = rao_runner.run(crac=crac, network=network, parameters=parameters)
# Out:
# 2026-04-29 10:22:28,052 - WARNING - powsybl - Running RAO using Open RAO version 7.2.0 from git commit dabb1be29b3205267fb84a8ba13bb998f3f05b9a.
# 2026-04-29 10:22:28,055 - WARNING - powsybl - A threshold for the flowCnec cnec1 - curative is defined in MW but the loadflow computation is in AC. It will be imprecisely converted by the RAO which could create uncoherent results due to side effects
# 2026-04-29 10:22:28,058 - WARNING - powsybl - A threshold for the flowCnec cnec1 - preventive is defined in MW but the loadflow computation is in AC. It will be imprecisely converted by the RAO which could create uncoherent results due to side effects
# 2026-04-29 10:22:28,062 - WARNING - powsybl - A threshold for the flowCnec cnec1 - curative is defined in MW but the loadflow computation is in AC. It will be imprecisely converted by the RAO which could create uncoherent results due to side effects
# 2026-04-29 10:22:28,064 - WARNING - powsybl - A threshold for the flowCnec cnec1 - preventive is defined in MW but the loadflow computation is in AC. It will be imprecisely converted by the RAO which could create uncoherent results due to side effects
# 2026-04-29 10:22:28,072 - INFO - powsybl - Network {CC0 SC0} has 3 buses and 4 branches
# 2026-04-29 10:22:28,075 - INFO - powsybl - Network {CC0 SC0} balance: active generation=100.0 MW, active load=100.0 MW, reactive generation=0.0 MVar, reactive load=50.0 MVar
# 2026-04-29 10:22:28,080 - INFO - powsybl - Network {CC0 SC0}, slack buses are [VL1_0] (method='Most meshed bus')
# 2026-04-29 10:22:28,083 - INFO - powsybl - Network {CC0 SC0}, reference bus is VL1_0 (method='First slack')
# 2026-04-29 10:22:28,087 - INFO - powsybl - Running AC sensitivity analysis with 6 factors and 1 contingencies
# 2026-04-29 10:22:28,092 - INFO - powsybl - Start AC loadflow on network {CC0 SC0}
# 2026-04-29 10:22:28,097 - INFO - powsybl - AC loadflow complete on network {CC0 SC0} (result=AcLoadFlowResult(outerLoopIterations=0, solverIterations=2, solverStatus=CONVERGED, outerLoopStatus=STABLE, slackBusActivePowerMismatch=0.17787785586249605, distributedActivePower=0.0))
# 2026-04-29 10:22:28,101 - INFO - powsybl - Simulate contingency 'coL1'
# 2026-04-29 10:22:28,105 - INFO - powsybl - Start AC loadflow on network {CC0 SC0}
# 2026-04-29 10:22:28,109 - INFO - powsybl - AC loadflow complete on network {CC0 SC0} (result=AcLoadFlowResult(outerLoopIterations=0, solverIterations=3, solverStatus=CONVERGED, outerLoopStatus=STABLE, slackBusActivePowerMismatch=0.3689737523340675, distributedActivePower=0.0))
# 2026-04-29 10:22:28,114 - INFO - powsybl - Initial sensitivity analysis: cost = -7.6 (functional: -7.6, virtual: 0.0)
# 2026-04-29 10:22:28,117 - INFO - powsybl - Limiting element #01: margin = 7.6 A, element L1 at state coL1 - curative, CNEC ID = "cnec1 - curative"
# 2026-04-29 10:22:28,120 - INFO - powsybl - Limiting element #02: margin = 68.25 A, element L1 at state preventive, CNEC ID = "cnec1 - preventive"
# 2026-04-29 10:22:28,122 - INFO - powsybl - ----- Preventive perimeter optimization [start]
# 2026-04-29 10:22:28,127 - INFO - powsybl - Stop criterion reached on Root leaf, cost: -68.25 (functional: -68.25, virtual: 0.0)
# 2026-04-29 10:22:28,130 - INFO - powsybl - Limiting element #01: margin = 68.25 A, element L1 at state preventive, CNEC ID = "cnec1 - preventive"
# 2026-04-29 10:22:28,132 - INFO - powsybl - Scenario "preventive": initial cost = -68.25 (functional: -68.25, virtual: 0.0), no remedial actions activated, cost after preventive optimization = -68.25 (functional: -68.25, virtual: 0.0)
# 2026-04-29 10:22:28,134 - INFO - powsybl - ----- Preventive perimeter optimization [end]
# 2026-04-29 10:22:28,136 - INFO - powsybl - Systematic sensitivity analysis after preventive remedial actions: cost = -7.6 (functional: -7.6, virtual: 0.0)
# 2026-04-29 10:22:28,138 - INFO - powsybl - Limiting element #01: margin = 7.6 A, element L1 at state coL1 - curative, CNEC ID = "cnec1 - curative"
# 2026-04-29 10:22:28,139 - INFO - powsybl - Limiting element #02: margin = 68.25 A, element L1 at state preventive, CNEC ID = "cnec1 - preventive"
# 2026-04-29 10:22:28,140 - INFO - powsybl - ----- Post-contingency perimeters optimization [start]
# 2026-04-29 10:22:28,148 - INFO - powsybl - Optimizing scenario post-contingency coL1.
# 2026-04-29 10:22:28,149 - INFO - powsybl - Optimizing curative state coL1 - curative.
# 2026-04-29 10:22:28,151 - INFO - powsybl - ----- Post-contingency perimeters optimization [end]
# 2026-04-29 10:22:28,152 - INFO - powsybl - Merging preventive and post-contingency RAO results:
# 2026-04-29 10:22:28,152 - INFO - powsybl - Limiting element #01: margin = 7.6 A, element L1 at state coL1 - curative, CNEC ID = "cnec1 - curative"
# 2026-04-29 10:22:28,153 - INFO - powsybl - Limiting element #02: margin = 68.25 A, element L1 at state preventive, CNEC ID = "cnec1 - preventive"
# 2026-04-29 10:22:28,155 - INFO - powsybl - Cost before RAO = -7.6 (functional: -7.6, virtual: 0.0), cost after RAO = -7.6 (functional: -7.6, virtual: 0.0)

# %% [markdown]
# In this case, no remedial actions were applied during the RAO, the network was already secure.
#
# We'll also need a GLSK file to perform redispatching to balance the network following the application of remedial actions. Angle remedial actions are indeed injection actions on generators or loads.

# %%
glsk = pp.rao.Glsk.from_file_source("./data/rao/monitoring/angle_monitoring/GlskB45test.xml")

# %% [markdown]
# Before running the angle monitoring algorithm, let's look at the angle cnec's situation in the network. As you can see in the crac, AngleCnec acCru1 is defined between exporting element VL2 and importing element VL1, at curative instant after contingency coL1 that disconnects line L1. A minimum threshold is defined at -6°. Let's look at the network after disconnecting L1:

# %%
network.disconnect("L1")
pp.loadflow.run_ac(network)
network.get_network_area_diagram()

# %% [markdown]
# AngleCnec is unsecure with an angle of -7.7 < -6°.
# Now let's run the angle monitoring algorithm.

# %%
result_with_angle_monitoring = rao_runner.run_angle_monitoring(crac=crac, network=network, rao_result=rao_result, load_flow_parameters=load_flow_parameters, provider_str="OpenLoadFlow", monitoring_glsk=glsk)
# Out:
# 2026-04-29 10:23:44,210 - INFO - powsybl - ----- ANGLE monitoring [start]
# 2026-04-29 10:23:44,212 - INFO - powsybl - -- 'ANGLE' Monitoring at state 'preventive' [start]
# 2026-04-29 10:23:44,214 - INFO - powsybl - Load-flow computation [start]
# 2026-04-29 10:23:44,217 - INFO - powsybl - Version: {repositoryName=powsybl-open-loadflow, mavenProjectVersion=2.2.0, gitVersion=783fc8661b7d6cadf3d464a88e2a91211e6a9ef9, gitBranch=UNKNOWN, buildTimestamp=2026-03-27T16:01:45.508Z}
# 2026-04-29 10:23:44,229 - INFO - powsybl - Parameters:
# ┌───────────────────────────┬───────────────────────────────────────────────────────────┬────────────────────────────────┐
# │ Category                  │ Name                                                      │ Value                          │
# ├───────────────────────────┼───────────────────────────────────────────────────────────┼────────────────────────────────┤
# │ Automation                │ simulateAutomationSystems                                 │ false                          │
# │ DC                        │ dcApproximationType                                       │ IGNORE_R                       │
# │                           │ dcPowerFactor                                             │ 1.0                            │
# │                           │ dcUseTransformerRatio                                     │ false                          │
# │ Debug                     │ alwaysUpdateNetwork                                       │ false                          │
# │                           │ debugDir                                                  │                                │
# │ FastRestart               │ actionableSwitchesIds                                     │ []                             │
# │                           │ actionableTransformersIds                                 │ []                             │
# │                           │ networkCacheEnabled                                       │ false                          │
# │ GeneratorVoltageControl   │ disableInconsistentVoltageControls                        │ false                          │
# │                           │ disableVoltageControlOfGeneratorsOutsideActivePowerLimits │ false                          │
# │                           │ extrapolateReactiveLimits                                 │ false                          │
# │                           │ fictitiousGeneratorVoltageControlCheckMode                │ FORCED                         │
# │                           │ forceTargetQInReactiveLimits                              │ false                          │
# │                           │ reactiveLimitsMaxPqPvSwitch                               │ 3                              │
# │                           │ reactivePowerDispatchMode                                 │ Q_EQUAL_PROPORTION             │
# │                           │ reactiveRangeCheckMode                                    │ MAX                            │
# │                           │ svcVoltageMonitoring                                      │ true                           │
# │                           │ voltagePerReactivePowerControl                            │ false                          │
# │                           │ voltageRemoteControl                                      │ true                           │
# │                           │ voltageRemoteControlRobustMode                            │ true                           │
# │ HVDC                      │ hvdcAcEmulation                                           │ true                           │
# │                           │ startWithFrozenACEmulation                                │ false                          │
# │ Model                     │ acDcNetwork                                               │ false                          │
# │                           │ asymmetrical                                              │ false                          │
# │                           │ dc                                                        │ false                          │
# │                           │ generatorsWithZeroMwTargetAreNotStarted                   │ true                           │
# │                           │ linePerUnitMode                                           │ IMPEDANCE                      │
# │                           │ lowImpedanceBranchMode                                    │ REPLACE_BY_ZERO_IMPEDANCE_LINE │
# │                           │ lowImpedanceThreshold                                     │ 1.0E-8                         │
# │                           │ twtSplitShuntAdmittance                                   │ true                           │
# │                           │ useLoadModel                                              │ false                          │
# │ NewtonKrylov              │ maxNewtonKrylovIterations                                 │ 100                            │
# │                           │ newtonKrylovLineSearch                                    │ false                          │
# │ NewtonRaphson             │ lineSearchStateVectorScalingMaxIteration                  │ 10                             │
# │                           │ lineSearchStateVectorScalingStepFold                      │ 1.3333333333333333             │
# │                           │ maxActivePowerMismatch                                    │ 0.01                           │
# │                           │ maxAngleMismatch                                          │ 1.0E-5                         │
# │                           │ maxNewtonRaphsonIterations                                │ 30                             │
# │                           │ maxRatioMismatch                                          │ 1.0E-5                         │
# │                           │ maxReactivePowerMismatch                                  │ 0.01                           │
# │                           │ maxSusceptanceMismatch                                    │ 1.0E-4                         │
# │                           │ maxVoltageChangeStateVectorScalingMaxDphi                 │ 0.17453292519943295            │
# │                           │ maxVoltageChangeStateVectorScalingMaxDv                   │ 0.1                            │
# │                           │ maxVoltageMismatch                                        │ 1.0E-4                         │
# │                           │ newtonRaphsonConvEpsPerEq                                 │ 1.0E-4                         │
# │                           │ newtonRaphsonStoppingCriteriaType                         │ UNIFORM_CRITERIA               │
# │                           │ stateVectorScalingMode                                    │ NONE                           │
# │ None                      │ computedComponentMode                                     │ MAIN_CONNECTED                 │
# │ OuterLoops                │ maxOuterLoopIterations                                    │ 20                             │
# │                           │ outerLoopNames                                            │                                │
# │ PhaseControl              │ phaseShifterControlMode                                   │ CONTINUOUS_WITH_DISCRETISATION │
# │                           │ phaseShifterRegulationOn                                  │ false                          │
# │ ReactivePowerControl      │ generatorReactivePowerRemoteControl                       │ false                          │
# │                           │ transformerReactivePowerControl                           │ false                          │
# │ ReferenceBus              │ referenceBusSelectionMode                                 │ FIRST_SLACK                    │
# │                           │ writeReferenceTerminals                                   │ true                           │
# │ Reporting                 │ reportedFeatures                                          │ []                             │
# │ ShuntVoltageControl       │ incrementalShuntControlOuterLoopMaxSectionShift           │ 3                              │
# │                           │ shuntCompensatorVoltageControlOn                          │ false                          │
# │                           │ shuntVoltageControlMode                                   │ WITH_GENERATOR_VOLTAGE_CONTROL │
# │ SlackDistribution         │ areaInterchangeControl                                    │ false                          │
# │                           │ areaInterchangeControlAreaType                            │ ControlArea                    │
# │                           │ areaInterchangePMaxMismatch                               │ 2.0                            │
# │                           │ balanceType                                               │ PROPORTIONAL_TO_GENERATION_P   │
# │                           │ countriesToBalance                                        │ [BG, BE, AL, RO, PT,  GR,  RS, │
# │                           │                                                           │ FR, UA, MK, ME,  CZ,  CH,  TR, │
# │                           │                                                           │ HU, IT, SK, SI,  DE,  HR,  PL, │
# │                           │                                                           │ AT, ES, BA, NL]                │
# │                           │ distributedSlack                                          │ true                           │
# │                           │ loadPowerFactorConstant                                   │ false                          │
# │                           │ maxSlackBusCount                                          │ 1                              │
# │                           │ mostMeshedSlackBusSelectorMaxNominalVoltagePercentile     │ 95.0                           │
# │                           │ plausibleActivePowerLimit                                 │ 10000.0                        │
# │                           │ readSlackBus                                              │ false                          │
# │                           │ slackBusCountryFilter                                     │ []                             │
# │                           │ slackBusPMaxMismatch                                      │ 1.0                            │
# │                           │ slackBusSelectionMode                                     │ MOST_MESHED                    │
# │                           │ slackBusesIds                                             │ []                             │
# │                           │ slackDistributionFailureBehavior                          │ LEAVE_ON_SLACK_BUS             │
# │                           │ useActiveLimits                                           │ true                           │
# │                           │ writeSlackBus                                             │ false                          │
# │ Solver                    │ acSolverType                                              │ NEWTON_RAPHSON                 │
# │ TransformerVoltageControl │ generatorVoltageControlMinNominalVoltage                  │ -1.0                           │
# │                           │ incrementalTransformerRatioTapControlOuterLoopMaxTapShift │ 3                              │
# │                           │ transformerVoltageControlMode                             │ WITH_GENERATOR_VOLTAGE_CONTROL │
# │                           │ transformerVoltageControlOn                               │ false                          │
# │                           │ transformerVoltageControlUseInitialTapPosition            │ false                          │
# │ VoltageControls           │ fixVoltageTargets                                         │ false                          │
# │                           │ maxPlausibleTargetVoltage                                 │ 1.2                            │
# │                           │ maxRealisticVoltage                                       │ 1.5                            │
# │                           │ minNominalVoltageRealisticVoltageCheck                    │ 0.0                            │
# │                           │ minNominalVoltageTargetVoltageCheck                       │ 20.0                           │
# │                           │ minPlausibleTargetVoltage                                 │ 0.8                            │
# │                           │ minRealisticVoltage                                       │ 0.5                            │
# │                           │ secondaryVoltageControl                                   │ false                          │
# │                           │ useReactiveLimits                                         │ true                           │
# │                           │ voltageTargetPriorities                                   │ [VOLTAGE_SOURCE_CONVERTER,     │
# │                           │                                                           │ GENERATOR, TRANSFORMER, SHUNT] │
# │ VoltageInit               │ voltageInitMode                                           │ UNIFORM_VALUES                 │
# │                           │ voltageInitModeOverride                                   │ NONE                           │
# └───────────────────────────┴───────────────────────────────────────────────────────────┴────────────────────────────────┘
# 2026-04-29 10:23:44,233 - INFO - powsybl - Outer loops: [DistributedSlack, AcHvdcAcEmulationLimits, VoltageMonitoring, ReactiveLimits]
# 2026-04-29 10:23:44,236 - INFO - powsybl - Network {CC0 SC0} has 3 buses and 3 branches
# 2026-04-29 10:23:44,238 - INFO - powsybl - Network {CC0 SC0} balance: active generation=100.0 MW, active load=100.0 MW, reactive generation=0.0 MVar, reactive load=50.0 MVar
# 2026-04-29 10:23:44,239 - INFO - powsybl - Network {CC0 SC0}, slack buses are [VL3_0] (method='Most meshed bus')
# 2026-04-29 10:23:44,241 - INFO - powsybl - Network {CC0 SC0}, reference bus is VL3_0 (method='First slack')
# 2026-04-29 10:23:44,243 - INFO - powsybl - Start AC loadflow on network {CC0 SC0}
# 2026-04-29 10:23:44,248 - INFO - powsybl - AC loadflow complete on network {CC0 SC0} (result=AcLoadFlowResult(outerLoopIterations=0, solverIterations=3, solverStatus=CONVERGED, outerLoopStatus=STABLE, slackBusActivePowerMismatch=0.3679344606782542, distributedActivePower=0.0))
# 2026-04-29 10:23:44,250 - INFO - powsybl - Load flow ran in 31 ms
# 2026-04-29 10:23:44,253 - INFO - powsybl - Load-flow computation [end]
# 2026-04-29 10:23:44,255 - INFO - powsybl - -- 'ANGLE' Monitoring at state 'preventive' [end]
# 2026-04-29 10:23:44,257 - INFO - powsybl - All ANGLE Cnecs are secure.
# 2026-04-29 10:23:44,259 - INFO - powsybl - Using base network 'phaseShifter' on variant 'ContingencyScenariob00f3d6a-068e-4b20-bb69-ed0d632c1b5a'
# 2026-04-29 10:23:44,261 - INFO - powsybl - -- 'ANGLE' Monitoring at state 'coL1 - curative' [start]
# 2026-04-29 10:23:44,263 - INFO - powsybl - Load-flow computation [start]
# 2026-04-29 10:23:44,264 - INFO - powsybl - Version: {repositoryName=powsybl-open-loadflow, mavenProjectVersion=2.2.0, gitVersion=783fc8661b7d6cadf3d464a88e2a91211e6a9ef9, gitBranch=UNKNOWN, buildTimestamp=2026-03-27T16:01:45.508Z}
# 2026-04-29 10:23:44,276 - INFO - powsybl - Parameters:
# ┌───────────────────────────┬───────────────────────────────────────────────────────────┬────────────────────────────────┐
# │ Category                  │ Name                                                      │ Value                          │
# ├───────────────────────────┼───────────────────────────────────────────────────────────┼────────────────────────────────┤
# │ Automation                │ simulateAutomationSystems                                 │ false                          │
# │ DC                        │ dcApproximationType                                       │ IGNORE_R                       │
# │                           │ dcPowerFactor                                             │ 1.0                            │
# │                           │ dcUseTransformerRatio                                     │ false                          │
# │ Debug                     │ alwaysUpdateNetwork                                       │ false                          │
# │                           │ debugDir                                                  │                                │
# │ FastRestart               │ actionableSwitchesIds                                     │ []                             │
# │                           │ actionableTransformersIds                                 │ []                             │
# │                           │ networkCacheEnabled                                       │ false                          │
# │ GeneratorVoltageControl   │ disableInconsistentVoltageControls                        │ false                          │
# │                           │ disableVoltageControlOfGeneratorsOutsideActivePowerLimits │ false                          │
# │                           │ extrapolateReactiveLimits                                 │ false                          │
# │                           │ fictitiousGeneratorVoltageControlCheckMode                │ FORCED                         │
# │                           │ forceTargetQInReactiveLimits                              │ false                          │
# │                           │ reactiveLimitsMaxPqPvSwitch                               │ 3                              │
# │                           │ reactivePowerDispatchMode                                 │ Q_EQUAL_PROPORTION             │
# │                           │ reactiveRangeCheckMode                                    │ MAX                            │
# │                           │ svcVoltageMonitoring                                      │ true                           │
# │                           │ voltagePerReactivePowerControl                            │ false                          │
# │                           │ voltageRemoteControl                                      │ true                           │
# │                           │ voltageRemoteControlRobustMode                            │ true                           │
# │ HVDC                      │ hvdcAcEmulation                                           │ true                           │
# │                           │ startWithFrozenACEmulation                                │ false                          │
# │ Model                     │ acDcNetwork                                               │ false                          │
# │                           │ asymmetrical                                              │ false                          │
# │                           │ dc                                                        │ false                          │
# │                           │ generatorsWithZeroMwTargetAreNotStarted                   │ true                           │
# │                           │ linePerUnitMode                                           │ IMPEDANCE                      │
# │                           │ lowImpedanceBranchMode                                    │ REPLACE_BY_ZERO_IMPEDANCE_LINE │
# │                           │ lowImpedanceThreshold                                     │ 1.0E-8                         │
# │                           │ twtSplitShuntAdmittance                                   │ true                           │
# │                           │ useLoadModel                                              │ false                          │
# │ NewtonKrylov              │ maxNewtonKrylovIterations                                 │ 100                            │
# │                           │ newtonKrylovLineSearch                                    │ false                          │
# │ NewtonRaphson             │ lineSearchStateVectorScalingMaxIteration                  │ 10                             │
# │                           │ lineSearchStateVectorScalingStepFold                      │ 1.3333333333333333             │
# │                           │ maxActivePowerMismatch                                    │ 0.01                           │
# │                           │ maxAngleMismatch                                          │ 1.0E-5                         │
# │                           │ maxNewtonRaphsonIterations                                │ 30                             │
# │                           │ maxRatioMismatch                                          │ 1.0E-5                         │
# │                           │ maxReactivePowerMismatch                                  │ 0.01                           │
# │                           │ maxSusceptanceMismatch                                    │ 1.0E-4                         │
# │                           │ maxVoltageChangeStateVectorScalingMaxDphi                 │ 0.17453292519943295            │
# │                           │ maxVoltageChangeStateVectorScalingMaxDv                   │ 0.1                            │
# │                           │ maxVoltageMismatch                                        │ 1.0E-4                         │
# │                           │ newtonRaphsonConvEpsPerEq                                 │ 1.0E-4                         │
# │                           │ newtonRaphsonStoppingCriteriaType                         │ UNIFORM_CRITERIA               │
# │                           │ stateVectorScalingMode                                    │ NONE                           │
# │ None                      │ computedComponentMode                                     │ MAIN_CONNECTED                 │
# │ OuterLoops                │ maxOuterLoopIterations                                    │ 20                             │
# │                           │ outerLoopNames                                            │                                │
# │ PhaseControl              │ phaseShifterControlMode                                   │ CONTINUOUS_WITH_DISCRETISATION │
# │                           │ phaseShifterRegulationOn                                  │ false                          │
# │ ReactivePowerControl      │ generatorReactivePowerRemoteControl                       │ false                          │
# │                           │ transformerReactivePowerControl                           │ false                          │
# │ ReferenceBus              │ referenceBusSelectionMode                                 │ FIRST_SLACK                    │
# │                           │ writeReferenceTerminals                                   │ true                           │
# │ Reporting                 │ reportedFeatures                                          │ []                             │
# │ ShuntVoltageControl       │ incrementalShuntControlOuterLoopMaxSectionShift           │ 3                              │
# │                           │ shuntCompensatorVoltageControlOn                          │ false                          │
# │                           │ shuntVoltageControlMode                                   │ WITH_GENERATOR_VOLTAGE_CONTROL │
# │ SlackDistribution         │ areaInterchangeControl                                    │ false                          │
# │                           │ areaInterchangeControlAreaType                            │ ControlArea                    │
# │                           │ areaInterchangePMaxMismatch                               │ 2.0                            │
# │                           │ balanceType                                               │ PROPORTIONAL_TO_GENERATION_P   │
# │                           │ countriesToBalance                                        │ [BG, BE, AL, RO, PT,  GR,  RS, │
# │                           │                                                           │ FR, UA, MK, ME,  CZ,  CH,  TR, │
# │                           │                                                           │ HU, IT, SK, SI,  DE,  HR,  PL, │
# │                           │                                                           │ AT, ES, BA, NL]                │
# │                           │ distributedSlack                                          │ true                           │
# │                           │ loadPowerFactorConstant                                   │ false                          │
# │                           │ maxSlackBusCount                                          │ 1                              │
# │                           │ mostMeshedSlackBusSelectorMaxNominalVoltagePercentile     │ 95.0                           │
# │                           │ plausibleActivePowerLimit                                 │ 10000.0                        │
# │                           │ readSlackBus                                              │ false                          │
# │                           │ slackBusCountryFilter                                     │ []                             │
# │                           │ slackBusPMaxMismatch                                      │ 1.0                            │
# │                           │ slackBusSelectionMode                                     │ MOST_MESHED                    │
# │                           │ slackBusesIds                                             │ []                             │
# │                           │ slackDistributionFailureBehavior                          │ LEAVE_ON_SLACK_BUS             │
# │                           │ useActiveLimits                                           │ true                           │
# │                           │ writeSlackBus                                             │ false                          │
# │ Solver                    │ acSolverType                                              │ NEWTON_RAPHSON                 │
# │ TransformerVoltageControl │ generatorVoltageControlMinNominalVoltage                  │ -1.0                           │
# │                           │ incrementalTransformerRatioTapControlOuterLoopMaxTapShift │ 3                              │
# │                           │ transformerVoltageControlMode                             │ WITH_GENERATOR_VOLTAGE_CONTROL │
# │                           │ transformerVoltageControlOn                               │ false                          │
# │                           │ transformerVoltageControlUseInitialTapPosition            │ false                          │
# │ VoltageControls           │ fixVoltageTargets                                         │ false                          │
# │                           │ maxPlausibleTargetVoltage                                 │ 1.2                            │
# │                           │ maxRealisticVoltage                                       │ 1.5                            │
# │                           │ minNominalVoltageRealisticVoltageCheck                    │ 0.0                            │
# │                           │ minNominalVoltageTargetVoltageCheck                       │ 20.0                           │
# │                           │ minPlausibleTargetVoltage                                 │ 0.8                            │
# │                           │ minRealisticVoltage                                       │ 0.5                            │
# │                           │ secondaryVoltageControl                                   │ false                          │
# │                           │ useReactiveLimits                                         │ true                           │
# │                           │ voltageTargetPriorities                                   │ [VOLTAGE_SOURCE_CONVERTER,     │
# │                           │                                                           │ GENERATOR, TRANSFORMER, SHUNT] │
# │ VoltageInit               │ voltageInitMode                                           │ UNIFORM_VALUES                 │
# │                           │ voltageInitModeOverride                                   │ NONE                           │
# └───────────────────────────┴───────────────────────────────────────────────────────────┴────────────────────────────────┘
# 2026-04-29 10:23:44,279 - INFO - powsybl - Outer loops: [DistributedSlack, AcHvdcAcEmulationLimits, VoltageMonitoring, ReactiveLimits]
# 2026-04-29 10:23:44,281 - INFO - powsybl - Network {CC0 SC0} has 3 buses and 3 branches
# 2026-04-29 10:23:44,283 - INFO - powsybl - Network {CC0 SC0} balance: active generation=100.0 MW, active load=100.0 MW, reactive generation=0.0 MVar, reactive load=50.0 MVar
# 2026-04-29 10:23:44,285 - INFO - powsybl - Network {CC0 SC0}, slack buses are [VL3_0] (method='Most meshed bus')
# 2026-04-29 10:23:44,286 - INFO - powsybl - Network {CC0 SC0}, reference bus is VL3_0 (method='First slack')
# 2026-04-29 10:23:44,288 - INFO - powsybl - Start AC loadflow on network {CC0 SC0}
# 2026-04-29 10:23:44,289 - INFO - powsybl - AC loadflow complete on network {CC0 SC0} (result=AcLoadFlowResult(outerLoopIterations=0, solverIterations=3, solverStatus=CONVERGED, outerLoopStatus=STABLE, slackBusActivePowerMismatch=0.3679344606782542, distributedActivePower=0.0))
# 2026-04-29 10:23:44,291 - INFO - powsybl - Load flow ran in 24 ms
# 2026-04-29 10:23:44,292 - INFO - powsybl - Load-flow computation [end]
# 2026-04-29 10:23:44,293 - INFO - powsybl - Applied the following remedial action(s) in order to reduce constraints on CNEC "acCur1": Injection L1 - 2
# 2026-04-29 10:23:44,295 - INFO - powsybl - Redispatching -50.0 MW in FR [start]
# 2026-04-29 10:23:44,296 - WARNING - powsybl - Redispatching failed: asked=-50.0 MW, applied=0.0 MW
# 2026-04-29 10:23:44,297 - INFO - powsybl - Redispatching -50.0 MW in FR [end]
# 2026-04-29 10:23:44,298 - INFO - powsybl - Load-flow computation [start]
# 2026-04-29 10:23:44,299 - INFO - powsybl - Version: {repositoryName=powsybl-open-loadflow, mavenProjectVersion=2.2.0, gitVersion=783fc8661b7d6cadf3d464a88e2a91211e6a9ef9, gitBranch=UNKNOWN, buildTimestamp=2026-03-27T16:01:45.508Z}
# 2026-04-29 10:23:44,307 - INFO - powsybl - Parameters:
# ┌───────────────────────────┬───────────────────────────────────────────────────────────┬────────────────────────────────┐
# │ Category                  │ Name                                                      │ Value                          │
# ├───────────────────────────┼───────────────────────────────────────────────────────────┼────────────────────────────────┤
# │ Automation                │ simulateAutomationSystems                                 │ false                          │
# │ DC                        │ dcApproximationType                                       │ IGNORE_R                       │
# │                           │ dcPowerFactor                                             │ 1.0                            │
# │                           │ dcUseTransformerRatio                                     │ false                          │
# │ Debug                     │ alwaysUpdateNetwork                                       │ false                          │
# │                           │ debugDir                                                  │                                │
# │ FastRestart               │ actionableSwitchesIds                                     │ []                             │
# │                           │ actionableTransformersIds                                 │ []                             │
# │                           │ networkCacheEnabled                                       │ false                          │
# │ GeneratorVoltageControl   │ disableInconsistentVoltageControls                        │ false                          │
# │                           │ disableVoltageControlOfGeneratorsOutsideActivePowerLimits │ false                          │
# │                           │ extrapolateReactiveLimits                                 │ false                          │
# │                           │ fictitiousGeneratorVoltageControlCheckMode                │ FORCED                         │
# │                           │ forceTargetQInReactiveLimits                              │ false                          │
# │                           │ reactiveLimitsMaxPqPvSwitch                               │ 3                              │
# │                           │ reactivePowerDispatchMode                                 │ Q_EQUAL_PROPORTION             │
# │                           │ reactiveRangeCheckMode                                    │ MAX                            │
# │                           │ svcVoltageMonitoring                                      │ true                           │
# │                           │ voltagePerReactivePowerControl                            │ false                          │
# │                           │ voltageRemoteControl                                      │ true                           │
# │                           │ voltageRemoteControlRobustMode                            │ true                           │
# │ HVDC                      │ hvdcAcEmulation                                           │ true                           │
# │                           │ startWithFrozenACEmulation                                │ false                          │
# │ Model                     │ acDcNetwork                                               │ false                          │
# │                           │ asymmetrical                                              │ false                          │
# │                           │ dc                                                        │ false                          │
# │                           │ generatorsWithZeroMwTargetAreNotStarted                   │ true                           │
# │                           │ linePerUnitMode                                           │ IMPEDANCE                      │
# │                           │ lowImpedanceBranchMode                                    │ REPLACE_BY_ZERO_IMPEDANCE_LINE │
# │                           │ lowImpedanceThreshold                                     │ 1.0E-8                         │
# │                           │ twtSplitShuntAdmittance                                   │ true                           │
# │                           │ useLoadModel                                              │ false                          │
# │ NewtonKrylov              │ maxNewtonKrylovIterations                                 │ 100                            │
# │                           │ newtonKrylovLineSearch                                    │ false                          │
# │ NewtonRaphson             │ lineSearchStateVectorScalingMaxIteration                  │ 10                             │
# │                           │ lineSearchStateVectorScalingStepFold                      │ 1.3333333333333333             │
# │                           │ maxActivePowerMismatch                                    │ 0.01                           │
# │                           │ maxAngleMismatch                                          │ 1.0E-5                         │
# │                           │ maxNewtonRaphsonIterations                                │ 30                             │
# │                           │ maxRatioMismatch                                          │ 1.0E-5                         │
# │                           │ maxReactivePowerMismatch                                  │ 0.01                           │
# │                           │ maxSusceptanceMismatch                                    │ 1.0E-4                         │
# │                           │ maxVoltageChangeStateVectorScalingMaxDphi                 │ 0.17453292519943295            │
# │                           │ maxVoltageChangeStateVectorScalingMaxDv                   │ 0.1                            │
# │                           │ maxVoltageMismatch                                        │ 1.0E-4                         │
# │                           │ newtonRaphsonConvEpsPerEq                                 │ 1.0E-4                         │
# │                           │ newtonRaphsonStoppingCriteriaType                         │ UNIFORM_CRITERIA               │
# │                           │ stateVectorScalingMode                                    │ NONE                           │
# │ None                      │ computedComponentMode                                     │ MAIN_CONNECTED                 │
# │ OuterLoops                │ maxOuterLoopIterations                                    │ 20                             │
# │                           │ outerLoopNames                                            │                                │
# │ PhaseControl              │ phaseShifterControlMode                                   │ CONTINUOUS_WITH_DISCRETISATION │
# │                           │ phaseShifterRegulationOn                                  │ false                          │
# │ ReactivePowerControl      │ generatorReactivePowerRemoteControl                       │ false                          │
# │                           │ transformerReactivePowerControl                           │ false                          │
# │ ReferenceBus              │ referenceBusSelectionMode                                 │ FIRST_SLACK                    │
# │                           │ writeReferenceTerminals                                   │ true                           │
# │ Reporting                 │ reportedFeatures                                          │ []                             │
# │ ShuntVoltageControl       │ incrementalShuntControlOuterLoopMaxSectionShift           │ 3                              │
# │                           │ shuntCompensatorVoltageControlOn                          │ false                          │
# │                           │ shuntVoltageControlMode                                   │ WITH_GENERATOR_VOLTAGE_CONTROL │
# │ SlackDistribution         │ areaInterchangeControl                                    │ false                          │
# │                           │ areaInterchangeControlAreaType                            │ ControlArea                    │
# │                           │ areaInterchangePMaxMismatch                               │ 2.0                            │
# │                           │ balanceType                                               │ PROPORTIONAL_TO_GENERATION_P   │
# │                           │ countriesToBalance                                        │ [BG, BE, AL, RO, PT,  GR,  RS, │
# │                           │                                                           │ FR, UA, MK, ME,  CZ,  CH,  TR, │
# │                           │                                                           │ HU, IT, SK, SI,  DE,  HR,  PL, │
# │                           │                                                           │ AT, ES, BA, NL]                │
# │                           │ distributedSlack                                          │ true                           │
# │                           │ loadPowerFactorConstant                                   │ false                          │
# │                           │ maxSlackBusCount                                          │ 1                              │
# │                           │ mostMeshedSlackBusSelectorMaxNominalVoltagePercentile     │ 95.0                           │
# │                           │ plausibleActivePowerLimit                                 │ 10000.0                        │
# │                           │ readSlackBus                                              │ false                          │
# │                           │ slackBusCountryFilter                                     │ []                             │
# │                           │ slackBusPMaxMismatch                                      │ 1.0                            │
# │                           │ slackBusSelectionMode                                     │ MOST_MESHED                    │
# │                           │ slackBusesIds                                             │ []                             │
# │                           │ slackDistributionFailureBehavior                          │ LEAVE_ON_SLACK_BUS             │
# │                           │ useActiveLimits                                           │ true                           │
# │                           │ writeSlackBus                                             │ false                          │
# │ Solver                    │ acSolverType                                              │ NEWTON_RAPHSON                 │
# │ TransformerVoltageControl │ generatorVoltageControlMinNominalVoltage                  │ -1.0                           │
# │                           │ incrementalTransformerRatioTapControlOuterLoopMaxTapShift │ 3                              │
# │                           │ transformerVoltageControlMode                             │ WITH_GENERATOR_VOLTAGE_CONTROL │
# │                           │ transformerVoltageControlOn                               │ false                          │
# │                           │ transformerVoltageControlUseInitialTapPosition            │ false                          │
# │ VoltageControls           │ fixVoltageTargets                                         │ false                          │
# │                           │ maxPlausibleTargetVoltage                                 │ 1.2                            │
# │                           │ maxRealisticVoltage                                       │ 1.5                            │
# │                           │ minNominalVoltageRealisticVoltageCheck                    │ 0.0                            │
# │                           │ minNominalVoltageTargetVoltageCheck                       │ 20.0                           │
# │                           │ minPlausibleTargetVoltage                                 │ 0.8                            │
# │                           │ minRealisticVoltage                                       │ 0.5                            │
# │                           │ secondaryVoltageControl                                   │ false                          │
# │                           │ useReactiveLimits                                         │ true                           │
# │                           │ voltageTargetPriorities                                   │ [VOLTAGE_SOURCE_CONVERTER,     │
# │                           │                                                           │ GENERATOR, TRANSFORMER, SHUNT] │
# │ VoltageInit               │ voltageInitMode                                           │ UNIFORM_VALUES                 │
# │                           │ voltageInitModeOverride                                   │ NONE                           │
# └───────────────────────────┴───────────────────────────────────────────────────────────┴────────────────────────────────┘
# 2026-04-29 10:23:44,308 - INFO - powsybl - Outer loops: [DistributedSlack, AcHvdcAcEmulationLimits, VoltageMonitoring, ReactiveLimits]
# 2026-04-29 10:23:44,309 - INFO - powsybl - Network {CC0 SC0} has 3 buses and 3 branches
# 2026-04-29 10:23:44,311 - INFO - powsybl - Network {CC0 SC0} balance: active generation=100.0 MW, active load=50.0 MW, reactive generation=0.0 MVar, reactive load=50.0 MVar
# 2026-04-29 10:23:44,312 - INFO - powsybl - Network {CC0 SC0}, slack buses are [VL3_0] (method='Most meshed bus')
# 2026-04-29 10:23:44,313 - INFO - powsybl - Network {CC0 SC0}, reference bus is VL3_0 (method='First slack')
# 2026-04-29 10:23:44,314 - INFO - powsybl - Start AC loadflow on network {CC0 SC0}
# 2026-04-29 10:23:44,316 - INFO - powsybl - Slack bus active power (-49.75370763087722 MW) distributed in 1 distribution iteration(s)
# 2026-04-29 10:23:44,317 - INFO - powsybl - AC loadflow complete on network {CC0 SC0} (result=AcLoadFlowResult(outerLoopIterations=1, solverIterations=5, solverStatus=CONVERGED, outerLoopStatus=STABLE, slackBusActivePowerMismatch=-0.10133730290570186, distributedActivePower=-49.75370763087722))
# 2026-04-29 10:23:44,318 - INFO - powsybl - Load flow ran in 18 ms
# 2026-04-29 10:23:44,319 - INFO - powsybl - Load-flow computation [end]
# 2026-04-29 10:23:44,320 - INFO - powsybl - -- 'ANGLE' Monitoring at state 'coL1 - curative' [end]
# 2026-04-29 10:23:44,320 - INFO - powsybl - All ANGLE Cnecs are secure.
# 2026-04-29 10:23:44,322 - INFO - powsybl - ----- ANGLE monitoring [end]
# 2026-04-29 10:23:44,322 - INFO - powsybl - All ANGLE Cnecs are secure.

# %%
df_angle_cnecs = result_with_angle_monitoring.get_angle_cnec_results()
df_angle_cnecs[['cnec_id', 'angle', 'margin']]
# Out:
#       cnec_id     angle    margin
# index
# 3      acCur1 -3.967853  2.032147

# %% [markdown]
# During the monitoring algorithm, a network action was applied, setting load LD2's value to 50 MW. The monitoring algorithm tried to perform the opposite redispatching action to maintain network balance, but scaling failed in our case, most likely because the network is so small. Balance was achieved during load flow computation via slack redistribution.
# Applied network action made AngleCnec acCur1 secure, by shifting its' angle from -7.7° to -3.8°.
#
# Only load actions and generator actions can be used to relieve angle cnecs. In the following example, a topological action is defined (open L3) but it isn't even considered to relieve AngleCnec acCur1.

# %%
network_2 = pp.network.load("./data/rao/monitoring/network.xiidm")
crac_2 = pp.rao.Crac.from_file_source(network_2, "./data/rao/monitoring/angle_monitoring/angle_monitoring_simple_case_with_topo.json")
rao_runner_2 = pp.rao.create_rao()
rao_result_2 = rao_runner_2.run(crac=crac_2, network=network_2, parameters=parameters)
# Out:
# 2026-04-29 10:23:50,604 - WARNING - powsybl - The nominalV is now fetched in the network so the value in the CRAC will not be read.
# 2026-04-29 10:23:50,605 - WARNING - powsybl - The nominalV is now fetched in the network so the value in the CRAC will not be read.
# 2026-04-29 10:23:50,606 - WARNING - powsybl - Usage methods are no longer used.
# 2026-04-29 10:23:50,607 - WARNING - powsybl - Usage methods are no longer used.
# 2026-04-29 10:23:50,610 - WARNING - powsybl - Running RAO using Open RAO version 7.2.0 from git commit dabb1be29b3205267fb84a8ba13bb998f3f05b9a.
# 2026-04-29 10:23:50,611 - WARNING - powsybl - A threshold for the flowCnec cnec1 - curative is defined in MW but the loadflow computation is in AC. It will be imprecisely converted by the RAO which could create uncoherent results due to side effects
# 2026-04-29 10:23:50,612 - WARNING - powsybl - A threshold for the flowCnec cnec1 - preventive is defined in MW but the loadflow computation is in AC. It will be imprecisely converted by the RAO which could create uncoherent results due to side effects
# 2026-04-29 10:23:50,613 - WARNING - powsybl - A threshold for the flowCnec cnec1 - curative is defined in MW but the loadflow computation is in AC. It will be imprecisely converted by the RAO which could create uncoherent results due to side effects
# 2026-04-29 10:23:50,614 - WARNING - powsybl - A threshold for the flowCnec cnec1 - preventive is defined in MW but the loadflow computation is in AC. It will be imprecisely converted by the RAO which could create uncoherent results due to side effects
# 2026-04-29 10:23:50,616 - INFO - powsybl - Network {CC0 SC0} has 3 buses and 4 branches
# 2026-04-29 10:23:50,617 - INFO - powsybl - Network {CC0 SC0} balance: active generation=100.0 MW, active load=100.0 MW, reactive generation=0.0 MVar, reactive load=50.0 MVar
# 2026-04-29 10:23:50,618 - INFO - powsybl - Network {CC0 SC0}, slack buses are [VL1_0] (method='Most meshed bus')
# 2026-04-29 10:23:50,619 - INFO - powsybl - Network {CC0 SC0}, reference bus is VL1_0 (method='First slack')
# 2026-04-29 10:23:50,621 - INFO - powsybl - Running AC sensitivity analysis with 6 factors and 1 contingencies
# 2026-04-29 10:23:50,622 - INFO - powsybl - Start AC loadflow on network {CC0 SC0}
# 2026-04-29 10:23:50,623 - INFO - powsybl - AC loadflow complete on network {CC0 SC0} (result=AcLoadFlowResult(outerLoopIterations=0, solverIterations=2, solverStatus=CONVERGED, outerLoopStatus=STABLE, slackBusActivePowerMismatch=0.17787785586249605, distributedActivePower=0.0))
# 2026-04-29 10:23:50,625 - INFO - powsybl - Simulate contingency 'coL1'
# 2026-04-29 10:23:50,626 - INFO - powsybl - Start AC loadflow on network {CC0 SC0}
# 2026-04-29 10:23:50,627 - INFO - powsybl - AC loadflow complete on network {CC0 SC0} (result=AcLoadFlowResult(outerLoopIterations=0, solverIterations=3, solverStatus=CONVERGED, outerLoopStatus=STABLE, slackBusActivePowerMismatch=0.3689737523340675, distributedActivePower=0.0))
# 2026-04-29 10:23:50,628 - INFO - powsybl - Initial sensitivity analysis: cost = -7.6 (functional: -7.6, virtual: 0.0)
# 2026-04-29 10:23:50,629 - INFO - powsybl - Limiting element #01: margin = 7.6 A, element L1 at state coL1 - curative, CNEC ID = "cnec1 - curative"
# 2026-04-29 10:23:50,630 - INFO - powsybl - Limiting element #02: margin = 68.25 A, element L1 at state preventive, CNEC ID = "cnec1 - preventive"
# 2026-04-29 10:23:50,631 - INFO - powsybl - ----- Preventive perimeter optimization [start]
# 2026-04-29 10:23:50,632 - INFO - powsybl - Stop criterion reached on Root leaf, cost: -68.25 (functional: -68.25, virtual: 0.0)
# 2026-04-29 10:23:50,633 - INFO - powsybl - Limiting element #01: margin = 68.25 A, element L1 at state preventive, CNEC ID = "cnec1 - preventive"
# 2026-04-29 10:23:50,634 - INFO - powsybl - Scenario "preventive": initial cost = -68.25 (functional: -68.25, virtual: 0.0), no remedial actions activated, cost after preventive optimization = -68.25 (functional: -68.25, virtual: 0.0)
# 2026-04-29 10:23:50,634 - INFO - powsybl - ----- Preventive perimeter optimization [end]
# 2026-04-29 10:23:50,635 - INFO - powsybl - Systematic sensitivity analysis after preventive remedial actions: cost = -7.6 (functional: -7.6, virtual: 0.0)
# 2026-04-29 10:23:50,636 - INFO - powsybl - Limiting element #01: margin = 7.6 A, element L1 at state coL1 - curative, CNEC ID = "cnec1 - curative"
# 2026-04-29 10:23:50,637 - INFO - powsybl - Limiting element #02: margin = 68.25 A, element L1 at state preventive, CNEC ID = "cnec1 - preventive"
# 2026-04-29 10:23:50,638 - INFO - powsybl - ----- Post-contingency perimeters optimization [start]
# 2026-04-29 10:23:50,640 - INFO - powsybl - Optimizing scenario post-contingency coL1.
# 2026-04-29 10:23:50,641 - INFO - powsybl - Optimizing curative state coL1 - curative.
# 2026-04-29 10:23:50,643 - INFO - powsybl - ----- Post-contingency perimeters optimization [end]
# 2026-04-29 10:23:50,644 - INFO - powsybl - Merging preventive and post-contingency RAO results:
# 2026-04-29 10:23:50,644 - INFO - powsybl - Limiting element #01: margin = 7.6 A, element L1 at state coL1 - curative, CNEC ID = "cnec1 - curative"
# 2026-04-29 10:23:50,645 - INFO - powsybl - Limiting element #02: margin = 68.25 A, element L1 at state preventive, CNEC ID = "cnec1 - preventive"
# 2026-04-29 10:23:50,646 - INFO - powsybl - Cost before RAO = -7.6 (functional: -7.6, virtual: 0.0), cost after RAO = -7.6 (functional: -7.6, virtual: 0.0)

# %%
print(rao_result_2.to_json())
# Out:
# {'type': 'RAO_RESULT', 'version': '1.8', 'info': 'Generated by Open RAO https://powsybl.readthedocs.io/projects/openrao', 'computationStatus': 'default', 'executionDetails': 'The RAO only went through first preventive', 'costResults': {'initial': {'functionalCost': -7.6, 'virtualCost': {'sensitivity-failure-cost': 0.0}}, 'preventive': {'functionalCost': -7.6, 'virtualCost': {'sensitivity-failure-cost': 0.0}}, 'outage': {'functionalCost': -7.6, 'virtualCost': {'sensitivity-failure-cost': 0.0}}, 'auto': {'functionalCost': -7.6, 'virtualCost': {'sensitivity-failure-cost': 0.0}}, 'curative': {'functionalCost': -7.6, 'virtualCost': {'sensitivity-failure-cost': 0.0}}}, 'computationStatusMap': [], 'flowCnecResults': [{'flowCnecId': 'cnec1 - curative', 'initial': {'ampere': {'margin': 7.6, 'side2': {'flow': 0.0}}, 'megawatt': {'margin': 5.0, 'side2': {'flow': 0.0}}}, 'preventive': {'ampere': {'margin': 7.6, 'side2': {'flow': 0.0}}, 'megawatt': {'margin': 5.0, 'side2': {'flow': 0.0}}}, 'auto': {'ampere': {'margin': 7.6, 'side2': {'flow': 0.0}}, 'megawatt': {'margin': 5.0, 'side2': {'flow': 0.0}}}, 'curative': {'ampere': {'margin': 7.6, 'side2': {'flow': 0.0}}, 'megawatt': {'margin': 5.0, 'side2': {'flow': 0.0}}}}, {'flowCnecId': 'cnec1 - preventive', 'initial': {'ampere': {'margin': 68.25, 'side2': {'flow': 83.68}}, 'megawatt': {'margin': 49.99, 'side2': {'flow': 50.01}}}, 'preventive': {'ampere': {'margin': 68.25, 'side2': {'flow': 83.68}}, 'megawatt': {'margin': 49.99, 'side2': {'flow': 50.01}}}}], 'networkActionResults': [], 'rangeActionResults': []}

# %%
glsk_2 = pp.rao.Glsk.from_file_source("./data/rao/monitoring/angle_monitoring/GlskB45test.xml")
result_with_angle_monitoring_2 = rao_runner_2.run_angle_monitoring(crac=crac_2, network=network_2, rao_result=rao_result_2, load_flow_parameters=load_flow_parameters, provider_str="OpenLoadFlow", monitoring_glsk=glsk_2)
# Out:
# 2026-04-29 10:24:02,278 - INFO - powsybl - UCTE GLSK importer could not import this document.
# 2026-04-29 10:24:02,279 - INFO - powsybl - CIM GLSK importer could import this document.
# 2026-04-29 10:24:02,282 - INFO - powsybl - ----- ANGLE monitoring [start]
# 2026-04-29 10:24:02,282 - INFO - powsybl - -- 'ANGLE' Monitoring at state 'preventive' [start]
# 2026-04-29 10:24:02,283 - INFO - powsybl - Load-flow computation [start]
# 2026-04-29 10:24:02,284 - INFO - powsybl - Version: {repositoryName=powsybl-open-loadflow, mavenProjectVersion=2.2.0, gitVersion=783fc8661b7d6cadf3d464a88e2a91211e6a9ef9, gitBranch=UNKNOWN, buildTimestamp=2026-03-27T16:01:45.508Z}
# 2026-04-29 10:24:02,292 - INFO - powsybl - Parameters:
# ┌───────────────────────────┬───────────────────────────────────────────────────────────┬────────────────────────────────┐
# │ Category                  │ Name                                                      │ Value                          │
# ├───────────────────────────┼───────────────────────────────────────────────────────────┼────────────────────────────────┤
# │ Automation                │ simulateAutomationSystems                                 │ false                          │
# │ DC                        │ dcApproximationType                                       │ IGNORE_R                       │
# │                           │ dcPowerFactor                                             │ 1.0                            │
# │                           │ dcUseTransformerRatio                                     │ false                          │
# │ Debug                     │ alwaysUpdateNetwork                                       │ false                          │
# │                           │ debugDir                                                  │                                │
# │ FastRestart               │ actionableSwitchesIds                                     │ []                             │
# │                           │ actionableTransformersIds                                 │ []                             │
# │                           │ networkCacheEnabled                                       │ false                          │
# │ GeneratorVoltageControl   │ disableInconsistentVoltageControls                        │ false                          │
# │                           │ disableVoltageControlOfGeneratorsOutsideActivePowerLimits │ false                          │
# │                           │ extrapolateReactiveLimits                                 │ false                          │
# │                           │ fictitiousGeneratorVoltageControlCheckMode                │ FORCED                         │
# │                           │ forceTargetQInReactiveLimits                              │ false                          │
# │                           │ reactiveLimitsMaxPqPvSwitch                               │ 3                              │
# │                           │ reactivePowerDispatchMode                                 │ Q_EQUAL_PROPORTION             │
# │                           │ reactiveRangeCheckMode                                    │ MAX                            │
# │                           │ svcVoltageMonitoring                                      │ true                           │
# │                           │ voltagePerReactivePowerControl                            │ false                          │
# │                           │ voltageRemoteControl                                      │ true                           │
# │                           │ voltageRemoteControlRobustMode                            │ true                           │
# │ HVDC                      │ hvdcAcEmulation                                           │ true                           │
# │                           │ startWithFrozenACEmulation                                │ false                          │
# │ Model                     │ acDcNetwork                                               │ false                          │
# │                           │ asymmetrical                                              │ false                          │
# │                           │ dc                                                        │ false                          │
# │                           │ generatorsWithZeroMwTargetAreNotStarted                   │ true                           │
# │                           │ linePerUnitMode                                           │ IMPEDANCE                      │
# │                           │ lowImpedanceBranchMode                                    │ REPLACE_BY_ZERO_IMPEDANCE_LINE │
# │                           │ lowImpedanceThreshold                                     │ 1.0E-8                         │
# │                           │ twtSplitShuntAdmittance                                   │ true                           │
# │                           │ useLoadModel                                              │ false                          │
# │ NewtonKrylov              │ maxNewtonKrylovIterations                                 │ 100                            │
# │                           │ newtonKrylovLineSearch                                    │ false                          │
# │ NewtonRaphson             │ lineSearchStateVectorScalingMaxIteration                  │ 10                             │
# │                           │ lineSearchStateVectorScalingStepFold                      │ 1.3333333333333333             │
# │                           │ maxActivePowerMismatch                                    │ 0.01                           │
# │                           │ maxAngleMismatch                                          │ 1.0E-5                         │
# │                           │ maxNewtonRaphsonIterations                                │ 30                             │
# │                           │ maxRatioMismatch                                          │ 1.0E-5                         │
# │                           │ maxReactivePowerMismatch                                  │ 0.01                           │
# │                           │ maxSusceptanceMismatch                                    │ 1.0E-4                         │
# │                           │ maxVoltageChangeStateVectorScalingMaxDphi                 │ 0.17453292519943295            │
# │                           │ maxVoltageChangeStateVectorScalingMaxDv                   │ 0.1                            │
# │                           │ maxVoltageMismatch                                        │ 1.0E-4                         │
# │                           │ newtonRaphsonConvEpsPerEq                                 │ 1.0E-4                         │
# │                           │ newtonRaphsonStoppingCriteriaType                         │ UNIFORM_CRITERIA               │
# │                           │ stateVectorScalingMode                                    │ NONE                           │
# │ None                      │ computedComponentMode                                     │ MAIN_CONNECTED                 │
# │ OuterLoops                │ maxOuterLoopIterations                                    │ 20                             │
# │                           │ outerLoopNames                                            │                                │
# │ PhaseControl              │ phaseShifterControlMode                                   │ CONTINUOUS_WITH_DISCRETISATION │
# │                           │ phaseShifterRegulationOn                                  │ false                          │
# │ ReactivePowerControl      │ generatorReactivePowerRemoteControl                       │ false                          │
# │                           │ transformerReactivePowerControl                           │ false                          │
# │ ReferenceBus              │ referenceBusSelectionMode                                 │ FIRST_SLACK                    │
# │                           │ writeReferenceTerminals                                   │ true                           │
# │ Reporting                 │ reportedFeatures                                          │ []                             │
# │ ShuntVoltageControl       │ incrementalShuntControlOuterLoopMaxSectionShift           │ 3                              │
# │                           │ shuntCompensatorVoltageControlOn                          │ false                          │
# │                           │ shuntVoltageControlMode                                   │ WITH_GENERATOR_VOLTAGE_CONTROL │
# │ SlackDistribution         │ areaInterchangeControl                                    │ false                          │
# │                           │ areaInterchangeControlAreaType                            │ ControlArea                    │
# │                           │ areaInterchangePMaxMismatch                               │ 2.0                            │
# │                           │ balanceType                                               │ PROPORTIONAL_TO_GENERATION_P   │
# │                           │ countriesToBalance                                        │ [BG, BE, AL, RO, PT,  GR,  RS, │
# │                           │                                                           │ FR, UA, MK, ME,  CZ,  CH,  TR, │
# │                           │                                                           │ HU, IT, SK, SI,  DE,  HR,  PL, │
# │                           │                                                           │ AT, ES, BA, NL]                │
# │                           │ distributedSlack                                          │ true                           │
# │                           │ loadPowerFactorConstant                                   │ false                          │
# │                           │ maxSlackBusCount                                          │ 1                              │
# │                           │ mostMeshedSlackBusSelectorMaxNominalVoltagePercentile     │ 95.0                           │
# │                           │ plausibleActivePowerLimit                                 │ 10000.0                        │
# │                           │ readSlackBus                                              │ false                          │
# │                           │ slackBusCountryFilter                                     │ []                             │
# │                           │ slackBusPMaxMismatch                                      │ 1.0                            │
# │                           │ slackBusSelectionMode                                     │ MOST_MESHED                    │
# │                           │ slackBusesIds                                             │ []                             │
# │                           │ slackDistributionFailureBehavior                          │ LEAVE_ON_SLACK_BUS             │
# │                           │ useActiveLimits                                           │ true                           │
# │                           │ writeSlackBus                                             │ false                          │
# │ Solver                    │ acSolverType                                              │ NEWTON_RAPHSON                 │
# │ TransformerVoltageControl │ generatorVoltageControlMinNominalVoltage                  │ -1.0                           │
# │                           │ incrementalTransformerRatioTapControlOuterLoopMaxTapShift │ 3                              │
# │                           │ transformerVoltageControlMode                             │ WITH_GENERATOR_VOLTAGE_CONTROL │
# │                           │ transformerVoltageControlOn                               │ false                          │
# │                           │ transformerVoltageControlUseInitialTapPosition            │ false                          │
# │ VoltageControls           │ fixVoltageTargets                                         │ false                          │
# │                           │ maxPlausibleTargetVoltage                                 │ 1.2                            │
# │                           │ maxRealisticVoltage                                       │ 1.5                            │
# │                           │ minNominalVoltageRealisticVoltageCheck                    │ 0.0                            │
# │                           │ minNominalVoltageTargetVoltageCheck                       │ 20.0                           │
# │                           │ minPlausibleTargetVoltage                                 │ 0.8                            │
# │                           │ minRealisticVoltage                                       │ 0.5                            │
# │                           │ secondaryVoltageControl                                   │ false                          │
# │                           │ useReactiveLimits                                         │ true                           │
# │                           │ voltageTargetPriorities                                   │ [VOLTAGE_SOURCE_CONVERTER,     │
# │                           │                                                           │ GENERATOR, TRANSFORMER, SHUNT] │
# │ VoltageInit               │ voltageInitMode                                           │ UNIFORM_VALUES                 │
# │                           │ voltageInitModeOverride                                   │ NONE                           │
# └───────────────────────────┴───────────────────────────────────────────────────────────┴────────────────────────────────┘
# 2026-04-29 10:24:02,293 - INFO - powsybl - Outer loops: [DistributedSlack, AcHvdcAcEmulationLimits, VoltageMonitoring, ReactiveLimits]
# 2026-04-29 10:24:02,294 - INFO - powsybl - Network {CC0 SC0} has 3 buses and 4 branches
# 2026-04-29 10:24:02,295 - INFO - powsybl - Network {CC0 SC0} balance: active generation=100.0 MW, active load=100.0 MW, reactive generation=0.0 MVar, reactive load=50.0 MVar
# 2026-04-29 10:24:02,296 - INFO - powsybl - Network {CC0 SC0}, slack buses are [VL1_0] (method='Most meshed bus')
# 2026-04-29 10:24:02,296 - INFO - powsybl - Network {CC0 SC0}, reference bus is VL1_0 (method='First slack')
# 2026-04-29 10:24:02,298 - INFO - powsybl - Start AC loadflow on network {CC0 SC0}
# 2026-04-29 10:24:02,299 - INFO - powsybl - AC loadflow complete on network {CC0 SC0} (result=AcLoadFlowResult(outerLoopIterations=0, solverIterations=2, solverStatus=CONVERGED, outerLoopStatus=STABLE, slackBusActivePowerMismatch=0.17787785586249605, distributedActivePower=0.0))
# 2026-04-29 10:24:02,300 - INFO - powsybl - Load flow ran in 14 ms
# 2026-04-29 10:24:02,301 - INFO - powsybl - Load-flow computation [end]
# 2026-04-29 10:24:02,302 - INFO - powsybl - -- 'ANGLE' Monitoring at state 'preventive' [end]
# 2026-04-29 10:24:02,303 - INFO - powsybl - All ANGLE Cnecs are secure.
# 2026-04-29 10:24:02,303 - INFO - powsybl - Using base network 'phaseShifter' on variant 'ContingencyScenario759b0bc9-016a-4ec8-8dbd-26ff5563139a'
# 2026-04-29 10:24:02,304 - INFO - powsybl - -- 'ANGLE' Monitoring at state 'coL1 - curative' [start]
# 2026-04-29 10:24:02,305 - INFO - powsybl - Load-flow computation [start]
# 2026-04-29 10:24:02,306 - INFO - powsybl - Version: {repositoryName=powsybl-open-loadflow, mavenProjectVersion=2.2.0, gitVersion=783fc8661b7d6cadf3d464a88e2a91211e6a9ef9, gitBranch=UNKNOWN, buildTimestamp=2026-03-27T16:01:45.508Z}
# 2026-04-29 10:24:02,314 - INFO - powsybl - Parameters:
# ┌───────────────────────────┬───────────────────────────────────────────────────────────┬────────────────────────────────┐
# │ Category                  │ Name                                                      │ Value                          │
# ├───────────────────────────┼───────────────────────────────────────────────────────────┼────────────────────────────────┤
# │ Automation                │ simulateAutomationSystems                                 │ false                          │
# │ DC                        │ dcApproximationType                                       │ IGNORE_R                       │
# │                           │ dcPowerFactor                                             │ 1.0                            │
# │                           │ dcUseTransformerRatio                                     │ false                          │
# │ Debug                     │ alwaysUpdateNetwork                                       │ false                          │
# │                           │ debugDir                                                  │                                │
# │ FastRestart               │ actionableSwitchesIds                                     │ []                             │
# │                           │ actionableTransformersIds                                 │ []                             │
# │                           │ networkCacheEnabled                                       │ false                          │
# │ GeneratorVoltageControl   │ disableInconsistentVoltageControls                        │ false                          │
# │                           │ disableVoltageControlOfGeneratorsOutsideActivePowerLimits │ false                          │
# │                           │ extrapolateReactiveLimits                                 │ false                          │
# │                           │ fictitiousGeneratorVoltageControlCheckMode                │ FORCED                         │
# │                           │ forceTargetQInReactiveLimits                              │ false                          │
# │                           │ reactiveLimitsMaxPqPvSwitch                               │ 3                              │
# │                           │ reactivePowerDispatchMode                                 │ Q_EQUAL_PROPORTION             │
# │                           │ reactiveRangeCheckMode                                    │ MAX                            │
# │                           │ svcVoltageMonitoring                                      │ true                           │
# │                           │ voltagePerReactivePowerControl                            │ false                          │
# │                           │ voltageRemoteControl                                      │ true                           │
# │                           │ voltageRemoteControlRobustMode                            │ true                           │
# │ HVDC                      │ hvdcAcEmulation                                           │ true                           │
# │                           │ startWithFrozenACEmulation                                │ false                          │
# │ Model                     │ acDcNetwork                                               │ false                          │
# │                           │ asymmetrical                                              │ false                          │
# │                           │ dc                                                        │ false                          │
# │                           │ generatorsWithZeroMwTargetAreNotStarted                   │ true                           │
# │                           │ linePerUnitMode                                           │ IMPEDANCE                      │
# │                           │ lowImpedanceBranchMode                                    │ REPLACE_BY_ZERO_IMPEDANCE_LINE │
# │                           │ lowImpedanceThreshold                                     │ 1.0E-8                         │
# │                           │ twtSplitShuntAdmittance                                   │ true                           │
# │                           │ useLoadModel                                              │ false                          │
# │ NewtonKrylov              │ maxNewtonKrylovIterations                                 │ 100                            │
# │                           │ newtonKrylovLineSearch                                    │ false                          │
# │ NewtonRaphson             │ lineSearchStateVectorScalingMaxIteration                  │ 10                             │
# │                           │ lineSearchStateVectorScalingStepFold                      │ 1.3333333333333333             │
# │                           │ maxActivePowerMismatch                                    │ 0.01                           │
# │                           │ maxAngleMismatch                                          │ 1.0E-5                         │
# │                           │ maxNewtonRaphsonIterations                                │ 30                             │
# │                           │ maxRatioMismatch                                          │ 1.0E-5                         │
# │                           │ maxReactivePowerMismatch                                  │ 0.01                           │
# │                           │ maxSusceptanceMismatch                                    │ 1.0E-4                         │
# │                           │ maxVoltageChangeStateVectorScalingMaxDphi                 │ 0.17453292519943295            │
# │                           │ maxVoltageChangeStateVectorScalingMaxDv                   │ 0.1                            │
# │                           │ maxVoltageMismatch                                        │ 1.0E-4                         │
# │                           │ newtonRaphsonConvEpsPerEq                                 │ 1.0E-4                         │
# │                           │ newtonRaphsonStoppingCriteriaType                         │ UNIFORM_CRITERIA               │
# │                           │ stateVectorScalingMode                                    │ NONE                           │
# │ None                      │ computedComponentMode                                     │ MAIN_CONNECTED                 │
# │ OuterLoops                │ maxOuterLoopIterations                                    │ 20                             │
# │                           │ outerLoopNames                                            │                                │
# │ PhaseControl              │ phaseShifterControlMode                                   │ CONTINUOUS_WITH_DISCRETISATION │
# │                           │ phaseShifterRegulationOn                                  │ false                          │
# │ ReactivePowerControl      │ generatorReactivePowerRemoteControl                       │ false                          │
# │                           │ transformerReactivePowerControl                           │ false                          │
# │ ReferenceBus              │ referenceBusSelectionMode                                 │ FIRST_SLACK                    │
# │                           │ writeReferenceTerminals                                   │ true                           │
# │ Reporting                 │ reportedFeatures                                          │ []                             │
# │ ShuntVoltageControl       │ incrementalShuntControlOuterLoopMaxSectionShift           │ 3                              │
# │                           │ shuntCompensatorVoltageControlOn                          │ false                          │
# │                           │ shuntVoltageControlMode                                   │ WITH_GENERATOR_VOLTAGE_CONTROL │
# │ SlackDistribution         │ areaInterchangeControl                                    │ false                          │
# │                           │ areaInterchangeControlAreaType                            │ ControlArea                    │
# │                           │ areaInterchangePMaxMismatch                               │ 2.0                            │
# │                           │ balanceType                                               │ PROPORTIONAL_TO_GENERATION_P   │
# │                           │ countriesToBalance                                        │ [BG, BE, AL, RO, PT,  GR,  RS, │
# │                           │                                                           │ FR, UA, MK, ME,  CZ,  CH,  TR, │
# │                           │                                                           │ HU, IT, SK, SI,  DE,  HR,  PL, │
# │                           │                                                           │ AT, ES, BA, NL]                │
# │                           │ distributedSlack                                          │ true                           │
# │                           │ loadPowerFactorConstant                                   │ false                          │
# │                           │ maxSlackBusCount                                          │ 1                              │
# │                           │ mostMeshedSlackBusSelectorMaxNominalVoltagePercentile     │ 95.0                           │
# │                           │ plausibleActivePowerLimit                                 │ 10000.0                        │
# │                           │ readSlackBus                                              │ false                          │
# │                           │ slackBusCountryFilter                                     │ []                             │
# │                           │ slackBusPMaxMismatch                                      │ 1.0                            │
# │                           │ slackBusSelectionMode                                     │ MOST_MESHED                    │
# │                           │ slackBusesIds                                             │ []                             │
# │                           │ slackDistributionFailureBehavior                          │ LEAVE_ON_SLACK_BUS             │
# │                           │ useActiveLimits                                           │ true                           │
# │                           │ writeSlackBus                                             │ false                          │
# │ Solver                    │ acSolverType                                              │ NEWTON_RAPHSON                 │
# │ TransformerVoltageControl │ generatorVoltageControlMinNominalVoltage                  │ -1.0                           │
# │                           │ incrementalTransformerRatioTapControlOuterLoopMaxTapShift │ 3                              │
# │                           │ transformerVoltageControlMode                             │ WITH_GENERATOR_VOLTAGE_CONTROL │
# │                           │ transformerVoltageControlOn                               │ false                          │
# │                           │ transformerVoltageControlUseInitialTapPosition            │ false                          │
# │ VoltageControls           │ fixVoltageTargets                                         │ false                          │
# │                           │ maxPlausibleTargetVoltage                                 │ 1.2                            │
# │                           │ maxRealisticVoltage                                       │ 1.5                            │
# │                           │ minNominalVoltageRealisticVoltageCheck                    │ 0.0                            │
# │                           │ minNominalVoltageTargetVoltageCheck                       │ 20.0                           │
# │                           │ minPlausibleTargetVoltage                                 │ 0.8                            │
# │                           │ minRealisticVoltage                                       │ 0.5                            │
# │                           │ secondaryVoltageControl                                   │ false                          │
# │                           │ useReactiveLimits                                         │ true                           │
# │                           │ voltageTargetPriorities                                   │ [VOLTAGE_SOURCE_CONVERTER,     │
# │                           │                                                           │ GENERATOR, TRANSFORMER, SHUNT] │
# │ VoltageInit               │ voltageInitMode                                           │ UNIFORM_VALUES                 │
# │                           │ voltageInitModeOverride                                   │ NONE                           │
# └───────────────────────────┴───────────────────────────────────────────────────────────┴────────────────────────────────┘
# 2026-04-29 10:24:02,315 - INFO - powsybl - Outer loops: [DistributedSlack, AcHvdcAcEmulationLimits, VoltageMonitoring, ReactiveLimits]
# 2026-04-29 10:24:02,316 - INFO - powsybl - Network {CC0 SC0} has 3 buses and 3 branches
# 2026-04-29 10:24:02,317 - INFO - powsybl - Network {CC0 SC0} balance: active generation=100.0 MW, active load=100.0 MW, reactive generation=0.0 MVar, reactive load=50.0 MVar
# 2026-04-29 10:24:02,318 - INFO - powsybl - Network {CC0 SC0}, slack buses are [VL3_0] (method='Most meshed bus')
# 2026-04-29 10:24:02,319 - INFO - powsybl - Network {CC0 SC0}, reference bus is VL3_0 (method='First slack')
# 2026-04-29 10:24:02,320 - INFO - powsybl - Start AC loadflow on network {CC0 SC0}
# 2026-04-29 10:24:02,321 - INFO - powsybl - AC loadflow complete on network {CC0 SC0} (result=AcLoadFlowResult(outerLoopIterations=0, solverIterations=3, solverStatus=CONVERGED, outerLoopStatus=STABLE, slackBusActivePowerMismatch=0.3679344606782542, distributedActivePower=0.0))
# 2026-04-29 10:24:02,322 - INFO - powsybl - Load flow ran in 15 ms
# 2026-04-29 10:24:02,323 - INFO - powsybl - Load-flow computation [end]
# 2026-04-29 10:24:02,324 - WARNING - powsybl - Remedial action Open L1 - 2 of AngleCnec acCur1 is ignored : it has an elementary action that's not an injection setpoint.
# 2026-04-29 10:24:02,325 - INFO - powsybl - Applied the following remedial action(s) in order to reduce constraints on CNEC "acCur1":
# 2026-04-29 10:24:02,327 - INFO - powsybl - -- 'ANGLE' Monitoring at state 'coL1 - curative' [end]
# 2026-04-29 10:24:02,327 - INFO - powsybl - Some ANGLE Cnecs are not secure:
# 2026-04-29 10:24:02,328 - INFO - powsybl - AngleCnec acCur1 (with importing network element VL1 and exporting network element VL2) at state coL1 - curative has an angle of -7.71°.
# 2026-04-29 10:24:02,329 - INFO - powsybl - ----- ANGLE monitoring [end]
# 2026-04-29 10:24:02,330 - INFO - powsybl - Some ANGLE Cnecs are not secure:
# 2026-04-29 10:24:02,331 - INFO - powsybl - AngleCnec acCur1 (with importing network element VL1 and exporting network element VL2) at state coL1 - curative has an angle of -7.71°.

# %%
df_angle_cnecs_2 = result_with_angle_monitoring_2.get_angle_cnec_results()
df_angle_cnecs_2[['cnec_id', 'angle', 'margin']]
# Out:
#       cnec_id     angle    margin
# index
# 1      acCur1 -7.713852 -4.713852
