# %%
import pypowsybl as pp

# %% [markdown]
# Load IEEE 14 buses network

# %%
n = pp.network.create_ieee14()

# %% [markdown]
# Run an AC load flow with default parameters

# %%
pp.loadflow.run_ac(n)
# Out:
# [ComponentResult(connected_component_num=0, synchronous_component_num=0, status=CONVERGED, iteration_count=3, slack_bus_id='VL4_0', slack_bus_active_power_mismatch=-0.006080859692958462)]

# %% [markdown]
# Generate a network area diagram for the full network

# %%
diagram = n.get_network_area_diagram()

# %%
diagram
